# %%
import os
import pandas as pd

df = pd.read_csv('seoul/seoul.csv')

# %%
df
# Out:
#            상호명   서비스    음식   편의성    가격          행정동     중분류         업종  \
# 0        L.A.D  1.05  0.74  0.71  0.91          서교동      한식  한식/백반/한정식
# 1      국수찾아닭만리  1.10  1.01  0.79  1.15  종로1.2.3.4가동  닭/오리요리  후라이드/양념치킨
# 2         동남식당  1.18  1.05  0.85  1.00  종로1.2.3.4가동      한식  한식/백반/한정식
# 3         강강술래  1.25  1.33  1.21  1.21         역삼1동      한식  한식/백반/한정식
# 4        한성양꼬치  1.01  1.14  0.81  0.82         역삼1동    유흥주점    꼬치구이전문점
# ...        ...   ...   ...   ...   ...          ...     ...        ...
# 1786        공감  0.79  0.78  0.49  0.66         역삼1동    유흥주점   기타일반유흥주점
# 1787  램브란트강남N점  4.06  4.29  1.49  3.83         역삼1동      한식  한식/백반/한정식
# 1788  육회란연어다홍대  1.42  1.42  1.37  1.41          서교동      한식  한식/백반/한정식
# 1789         솔  1.40  1.13  0.95  1.40          서교동      양식   정통양식/경양식
# 1790       일마레  1.29  0.97  0.87  0.99          서교동      양식   정통양식/경양식
#
#                                         naver_map_url
# 0     https://m.place.naver.com/restaurant/1857845585
# ...

# %%
f_path = 'data/'
df.to_pickle(os.path.join(f_path, "seoul.pkl"))

# %%
df_test = pd.read_pickle(os.path.join(f_path, "seoul.pkl"))

# %%
df_test
# Out:
#            상호명   서비스    음식   편의성    가격          행정동     중분류         업종  \
# 0        L.A.D  1.05  0.74  0.71  0.91          서교동      한식  한식/백반/한정식
# 1      국수찾아닭만리  1.10  1.01  0.79  1.15  종로1.2.3.4가동  닭/오리요리  후라이드/양념치킨
# 2         동남식당  1.18  1.05  0.85  1.00  종로1.2.3.4가동      한식  한식/백반/한정식
# 3         강강술래  1.25  1.33  1.21  1.21         역삼1동      한식  한식/백반/한정식
# 4        한성양꼬치  1.01  1.14  0.81  0.82         역삼1동    유흥주점    꼬치구이전문점
# ...        ...   ...   ...   ...   ...          ...     ...        ...
# 1786        공감  0.79  0.78  0.49  0.66         역삼1동    유흥주점   기타일반유흥주점
# 1787  램브란트강남N점  4.06  4.29  1.49  3.83         역삼1동      한식  한식/백반/한정식
# 1788  육회란연어다홍대  1.42  1.42  1.37  1.41          서교동      한식  한식/백반/한정식
# 1789         솔  1.40  1.13  0.95  1.40          서교동      양식   정통양식/경양식
# 1790       일마레  1.29  0.97  0.87  0.99          서교동      양식   정통양식/경양식
#
#                                         naver_map_url
# 0     https://m.place.naver.com/restaurant/1857845585
# ...
